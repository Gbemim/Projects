# %%
api_key = "AIzaSyD5L7QUOO5Hpf2QVRwCJ2zUTzxOdWvXsPM"

# %%
from googleapiclient.discovery import build

# %%
import re

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
request = youtube.search().list(part='snippet', maxResults=5, type='video', order='date')

# %%
res = request.execute()

# %%
for aa in res['items']:
    print(aa)
    print("\n\n")

res
# Out:
# {'kind': 'youtube#searchResult', 'etag': 'sRymZv3sm6OpDCW6ToS9hau5rr4', 'id': {'kind': 'youtube#video', 'videoId': 'UWvqP5xPxmw'}, 'snippet': {'publishedAt': '2020-08-18T15:35:18Z', 'channelId': 'UCnpqjEw2RHDBNVGDe8pI7tw', 'title': 'EasyPact Molded Case Circuit Breakers EZS 100A AUX SHT Installation | Schneider Electric Support', 'description': 'How to video demonstation for EasyPact EZS molded case circuit breakers (MCCB) regarding the AUX SHT installation. ▻Learn More: ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UWvqP5xPxmw/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/UWvqP5xPxmw/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/UWvqP5xPxmw/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'Schneider Electric', 'liveBroadcastContent': 'none', 'publishTime': '2020-08-18T15:35:18Z'}}
#
#
#
# ...

# %%
for title in res['items']:
    print(title['snippet']['description'])
    print("\n")
# Out:
# How to video demonstation for EasyPact EZS molded case circuit breakers (MCCB) regarding the AUX SHT installation. ▻Learn More: ...
#
#
# ACCESS the FULL COURSE here: https://academy.zenva.com/product/javascript-game-development-with-kontra-js-match-3/?zva_src=youtube-fullstackmd ...
#
#
# Cada vez son más los clientes de micoca-cola.cl que eligen envases retornables. Una de ellas es Camila Miranda, una joven ingeniera que contó a Journey las ...
#
#
# Qualidade de vida, atividade física e saúde Atividade Física e redução do comportamento sedentário para promoção da saúde e qualidade de vida.
#
#
# Дізнавайся про все першим, підписавшись на наш канал! Підписуйся на наші інші канали також: — Новини: https://bit.ly/37XeARq — Проекти: ...

# %%
for title in res['items']:
    descrip = title['snippet']['description']
    # its = re.search("and", descrip)
    if 'atividade' in descrip:
        print(title['snippet']['description'])
        print("\n")
# Out:
# Qualidade de vida, atividade física e saúde Atividade Física e redução do comportamento sedentário para promoção da saúde e qualidade de vida.

# %%
for title in res["items"]:
    descrip = title["snippet"]["description"]
    inputOfUser = input("Indicate: ")
    if inputOfUser in descrip:
        print(title["snippet"]["description"])
        print("\n")
    # elif inputOfUser == "":
    #     print("There is no promo code from this supplier")
# Out:
# How to video demonstation for EasyPact EZS molded case circuit breakers (MCCB) regarding the AUX SHT installation. ▻Learn More: ...
#
#
# ACCESS the FULL COURSE here: https://academy.zenva.com/product/javascript-game-development-with-kontra-js-match-3/?zva_src=youtube-fullstackmd ...
#
#
# Cada vez son más los clientes de micoca-cola.cl que eligen envases retornables. Una de ellas es Camila Miranda, una joven ingeniera que contó a Journey las ...
#
#
# Qualidade de vida, atividade física e saúde Atividade Física e redução do comportamento sedentário para promoção da saúde e qualidade de vida.
#
#
# Дізнавайся про все першим, підписавшись на наш канал! Підписуйся на наші інші канали також: — Новини: https://bit.ly/37XeARq — Проекти: ...
